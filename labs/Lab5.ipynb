# %% [markdown]
# # Лабораторная работа №5
# # Рекурсия. Фракталы.

# %% [markdown]
# ## Выполнил студент группы БВТ2005 Камышев Владимир Владимирович
# ***

# %% [markdown]
# ### Задание:
# Реализовать генерацию заданного типа фрактала с применением рекурсивных функций.
#
#
# Добавить возможность задания глубины фрактала.
#
#
# Оценить глубину рекурсии.
#
#
# Построить таблицу зависимости времени построения от глубины фрактала.

# %% [markdown]
# ### Список фракталов:
#
# Кривая Коха
# | Кривая Гильберта
# | Кривая Серпинского
# | Салфетка Серпинского
# | Ковер Серпинского
# | Дерево Пифагора

# %% [markdown]
# ### Выполнение:

# %%
#Кривая Коха

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom     
        self.state = axiom     
        self.width = width      
        self.length = length    
        self.angle = angle      
        self.t = t   
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)    
        self.t.up()             
        self.t.setpos(start_pos)    
        self.t.seth(start_angle)    
        self.t.down() 
        for move in self.state:
            if move == 'F':
                self.t.forward(self.length)
            elif move == '+':
                self.t.left(self.angle)
            elif move == '-':
                self.t.right(self.angle)
       
        screen.update()
        screen.mainloop()
    
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()

    

width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

 
t = turtle.Turtle()
t.ht()          
 
pen_width = 1   
f_len = 1     
angle = 60    

l_sys = LSystem2D(t, "F", pen_width, f_len, angle)
l_sys.add_rules(("F", "F+F--F+F"))
l_sys.generate_path(6)
l_sys.draw_turtle( (-900, -300), 0)

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/1310012023.py in <module>
#      63 l_sys.draw_turtle( (-900, -300), 0)
#      64
# ---> 65 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:

# %%
#Кривая Гильберта

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom     
        self.state = axiom      
        self.width = width      
        self.length = length    
        self.angle = angle     
        self.t = t   
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)   
        self.t.up()             
        self.t.setpos(start_pos)   
        self.t.seth(start_angle)  
        self.t.down()              
        for move in self.state:
            if move == 'F':
                self.t.forward(self.length)
            elif move == '+':
                self.t.left(self.angle)
            elif move == '-':
                self.t.right(self.angle)
        
        
        screen.update()
        screen.mainloop()      
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()


width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

 
t = turtle.Turtle()
t.ht()          
 
pen_width = 1  
f_len = 5     
angle = 90      

l_sys = LSystem2D(t, "A", pen_width, f_len, angle)
l_sys.add_rules(("A", "-BF+AFA+FB-"), ("B","+AF-BFB-FA+"))
l_sys.generate_path(5)
l_sys.draw_turtle( (-100, 500), 0)


turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/1717355978.py in <module>
#      63
#      64
# ---> 65 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:

# %%
#Кривая Серпинского

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom     
        self.state = axiom      
        self.width = width     
        self.length = length    
        self.angle = angle     
        self.t = t   
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)   
        self.t.up()            
        self.t.setpos(start_pos)    
        self.t.seth(start_angle)    
        self.t.down()               

        for move in self.state:
            if move == 'F':
                self.t.forward(self.length)
            elif move == 'G':
                self.t.forward(self.length)
            elif move == '+':
                self.t.left(self.angle)
            elif move == '-':
                self.t.right(self.angle)
        
        screen.update()
        screen.mainloop()  
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()

width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

t = turtle.Turtle()
t.ht()          
 
pen_width = 1  
f_len = 3     
angle = 45    

l_sys = LSystem2D(t, "F--XF--F--XF", pen_width, f_len, angle)
l_sys.add_rules(("X", "XF+G+XF--F--XF+G+X"))
l_sys.generate_path(6)
l_sys.draw_turtle( (-100, 400), 0)

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/713989035.py in <module>
#      62 l_sys.draw_turtle( (-100, 400), 0)
#      63
# ---> 64 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:

# %%
#Салфетка Серпинского

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom      
        self.state = axiom      
        self.width = width     
        self.length = length    
        self.angle = angle      
        self.t = t   
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)    
        self.t.up()             
        self.t.setpos(start_pos)   
        self.t.seth(start_angle)    
        self.t.down()               
        for move in self.state:
            if move == 'A' or move == 'B':
                self.t.forward(self.length)
            elif move == '+':
                self.t.left(self.angle)
            elif move == '-':
                self.t.right(self.angle)
        
        screen.update()
        screen.mainloop()       
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()


width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

 
t = turtle.Turtle()
t.ht()          
 
pen_width = 1  
f_len = 2     
angle = 60      

l_sys = LSystem2D(t, "A", pen_width, f_len, angle)
l_sys.add_rules(("A", "B-A-B"), ("B", "A+B+A"))
l_sys.generate_path(8)
l_sys.draw_turtle( (0, 0), 0)

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/2513168933.py in <module>
#      61 l_sys.draw_turtle( (0, 0), 0)
#      62
# ---> 63 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:

# %%
#Ковёр Серпинского

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom     
        self.state = axiom      
        self.width = width      
        self.length = length   
        self.angle = angle     
        self.t = t    
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)    
        self.t.up()            
        self.t.setpos(start_pos)    
        self.t.seth(start_angle)   
        self.t.down()               
        for move in self.state:
            if move == 'F':
                self.t.forward(self.length)
            elif move == 'G':
                self.t.forward(self.length)
            elif move == '+':
                self.t.left(self.angle)
            elif move == '-':
                self.t.right(self.angle)
        
        screen.update()
        screen.mainloop()       
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()


width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

t = turtle.Turtle()
t.ht()          
 
pen_width = 1   
f_len = 3   
angle = 90      

l_sys = LSystem2D(t, "F", pen_width, f_len, angle)
l_sys.add_rules(("F", "F+F-F-F-G+F+F+F-F"), ("G", "GGG"))
l_sys.generate_path(4)
l_sys.draw_turtle( (100, 100), 0)

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/1897299549.py in <module>
#      62 l_sys.draw_turtle( (100, 100), 0)
#      63
# ---> 64 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:

# %%
#Дерево Пифагора

import turtle

class LSystem2D:
    def __init__(self, t, axiom, width, length, angle):
        self.axiom = axiom      
        self.state = axiom    
        self.width = width      
        self.length = length    
        self.angle = angle    
        self.t = t    
        self.rules = {}
        self.t.pensize(self.width)
 
    def draw_turtle(self, start_pos, start_angle):
        turtle.tracer(1, 0)  
        self.t.up()             
        self.t.setpos(start_pos)    
        self.t.seth(start_angle)    
        self.t.down()               
        stack = []
        for move in self.state:
            if move == '1' or move == '0':
                self.t.forward(self.length)
            elif move == '[':
                stack.append(t.heading())
                stack.append(t.pos())
                self.t.left(self.angle)
            elif move == ']':
                pos = stack.pop()
                t.penup()
                t.setpos(pos[0], pos[1])
                t.pendown()
                t.setheading(stack.pop())
                self.t.right(self.angle)
        screen.update()
        screen.mainloop()       
    
        
    
    def add_rules(self, *rules):
        for key, value in rules:
            self.rules[key] = value
            
    def generate_path(self, n_iter):
        for n in range(n_iter):
            for key, value in self.rules.items():
                self.state = self.state.replace(key, value.lower())
 
            self.state = self.state.upper()


width = 1920
height = 1080
screen = turtle.Screen()
screen.setup(width, height, 0, 0)

 
t = turtle.Turtle()
t.ht()         
 
pen_width = 1   
f_len = 0.5   
angle = 45   

l_sys = LSystem2D(t, "0", pen_width, f_len, angle)
l_sys.add_rules(("0", "1[0]0"), ("1", "11"))
l_sys.generate_path(10)
l_sys.draw_turtle( (-800, 0), 0)

turtle.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# C:\Users\7F2A~1\AppData\Local\Temp/ipykernel_15604/3161398330.py in <module>
#      70 l_sys.draw_turtle( (-800, 0), 0)
#      71
# ---> 72 turtle.exitonclick()
#
# C:\new\lib\turtle.py in exitonclick()
#
# Terminator:
